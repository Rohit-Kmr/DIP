# %%
from matplotlib.image import *
from matplotlib.pyplot import *
import math as mt
import numpy as np
from PIL import Image

# %%
image=imread(r"C:\Users\DUCS-33\Documents\New folder\DIP-master\img.jpg")

# %%
temp=[]
for i in range(image.shape[0]):
    temp2=0
    temp3=[]
    for j in range(image.shape[1]):
        temp2=image[i][j][0]*0.3+image[i][j][1]*0.59+image[i][j][2]*0.11
        #if temp2>0:
        temp2=mt.floor(temp2)
        temp3.append(temp2)
    temp.append(list(temp3))
temp=np.array(temp)

# %%
image=temp
imshow(image,cmap="gray")

# %%
and_ar=[[255]*image.shape[1]]*image.shape[0]
and_ar=np.array(and_ar)

# %%
for i in range(100,200):
    for j in range(200,350):
        and_ar[i,j]=0

# %%
imshow(and_ar,cmap="gray")

# %%
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        image[i,j]=image[i,j] | and_ar[i,j]

# %%
imshow(image,cmap="gray")
