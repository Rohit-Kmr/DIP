# %%
from matplotlib.image import *
from matplotlib.pyplot import *
import math as mt
import numpy as np

# %%
img=imread("C:\\Users\\Rohit\\Documents\\GitHub\\DIP\\img.jpg")

# %%
imshow(img)

# %%
c=255/mt.log(np.max(img)+1)

# %%
one=np.ones(img.shape)
temp=np.add(img,one)
img2=(c*np.log(temp)).astype(int)
imshow(img2)

# %%
gamma=5
temp=(c*(img**(1/gamma))
img2=temp.astype(int)
imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
