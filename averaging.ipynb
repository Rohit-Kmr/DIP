# %%
from matplotlib.image import *
from matplotlib.pyplot import *
import math as mt
import numpy as np
from PIL import Image
from random import *

# %%
image=imread(r"C:\Users\DUCS-33\Documents\New folder\DIP-master\img.jpg")

# %%
temp=[]
for i in range(image.shape[0]):
    temp2=0
    temp3=[]
    for j in range(image.shape[1]):
        temp2=image[i][j][0]*0.3+image[i][j][1]*0.59+image[i][j][2]*0.11
        #if temp2>0:
        temp2=mt.floor(temp2)
        temp3.append(temp2)
    temp.append(list(temp3))
temp=np.array(temp)

# %%
image=temp
imshow(image,cmap="gray")

# %%
img1=np.copy(image)
img2=np.copy(image)
img3=np.copy(image)
img4=np.copy(image)
img5=np.copy(image)

# %%
seed(1)
for _ in range(100):
    i=randint(0,image.shape[0]-1)
    j=randint(0,image.shape[1]-1)
    value=randint(0,1)
    if value==1:
        value=255
    img1[i,j]=value

seed(100) 
for _ in range(100):
    i=randint(0,image.shape[0]-1)
    j=randint(0,image.shape[1]-1)
    value=randint(0,1)
    if value==1:
        value=255
    img2[i,j]=value
    
seed(200)
for _ in range(100):
    i=randint(0,image.shape[0]-1)
    j=randint(0,image.shape[1]-1)
    value=randint(0,1)
    if value==1:
        value=255
    img3[i,j]=value

    
seed(300)
for _ in range(100):
    i=randint(0,image.shape[0]-1)
    j=randint(0,image.shape[1]-1)
    value=randint(0,1)
    if value==1:
        value=255
    img4[i,j]=value

# %%
seed(400)
for _ in range(100):
    i=randint(0,image.shape[0]-1)
    j=randint(0,image.shape[1]-1)
    value=randint(0,1)
    if value==1:
        value=255
    img5[i,j]=value

# %%
imshow(image,cmap="gray")

# %%
imshow(img1,cmap="gray")

# %%
imshow(img2,cmap="gray")

# %%
imshow(img3,cmap="gray")

# %%
imshow(img4,cmap="gray")

# %%
imshow(img5,cmap="gray")

# %%
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        img1[i,j]=(img1[i,j]+img2[i,j]+img3[i,j]+img4[i,j]+img5[i,j])//5

# %%
imshow(img1,cmap="gray")
